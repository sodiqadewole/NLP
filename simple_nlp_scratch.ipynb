# %% [markdown]
# #### Load Data

# %%
import pandas as pd

tweets_data = pd.read_csv("SavedTweets.csv")

# %%
import re

### Remove punctuations
text1 = "Call me Ishmael. Some years ago - never mind how long precisely - having little or no money in my purse, and nothing particular..."

punctuation_free_text = re.sub(r'[^\w\s]', '', text1)

"""
'Call me Ishmael Some years ago  never mind how long precisely  having little or no money in my purse and nothing particular'
"""

### Remove numbers
text = text1.lower()

text2 = "2:43PM: It is announced that flight EK-712 is delayed due to the..."
text = text2.lower()
non_numeric_text = re.sub(r'\d+', '', text2)

"""
':pm: it is announced that flight ek- is delayed due to the...'
"""

# %% [markdown]
# #### Tokenization

# %%
import nltk

nltk.download('punkt_tab')
from nltk import word_tokenize

tokens = word_tokenize("The quick brown fox jumps over the lazy dog.")

"""
['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', '.']
"""

print(tokens)
# Out:
# ['The', 'quick', 'brown', 'fox', 'jumps', 'over', 'the', 'lazy', 'dog', '.']
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\adewo\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!

# %% [markdown]
# #### Remove stop words

# %%
# Removing stop words
import nltk
nltk.download('stopwords')

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))
print(list(stop_words)[5:])
# Out:
# ['mightn', 'no', 'as', 'most', "i'd", 'it', "we'll", 'should', 'your', 'hasn', 'have', 'at', 'nor', 'into', 'about', "she'd", "she's", 'she', 'a', 'shan', "he's", 'being', "needn't", 'her', 'up', 'didn', "we've", 'such', 'don', 'between', "i've", 'they', "he'd", 'from', 'having', 'mustn', 'himself', 'my', "they'd", 'them', 've', 'for', 'of', "weren't", "we'd", "you're", 'd', 'once', "shan't", 'yours', 'all', 'does', 'off', 'own', 'or', 'out', "you'll", 'doesn', 'again', 'each', 'very', 'ourselves', 't', 'weren', 'where', 'the', 'll', 'what', 'been', 'you', 'more', "he'll", 'above', "isn't", 'below', 'can', 'wasn', 'any', 'has', 'then', 'm', 'these', 'than', 'over', "she'll", 'an', 'myself', 'aren', "mightn't", 'while', 'whom', 'ma', 'had', 'too', 'until', 'that', 'both', 's', 'hers', 'y', 'to', "hasn't", 'by', 'our', 'this', 'me', 'its', 'were', 'doing', "it'll", "i'll", "wasn't", "won't", "they're", "they'll", 'are', 'who', 'couldn', 'but', 'itself', "that'll", 'against', "it's", 'w
# ...

# %%
filtered_tokens = [word for word in tokens if word.lower() not in stop_words]

print(filtered_tokens)
# Out:
# ['quick', 'brown', 'fox', 'jumps', 'lazy', 'dog', '.']
